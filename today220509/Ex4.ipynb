# %%
from konlpy.corpus import kolaw
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
t_data=kolaw.open('constitution.txt').read()

# %%
t_data[:40]
# Out:
# '대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로'

# %%
from konlpy.corpus import kobill
kobill.fileids()
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
t_data2=kobill.open('1809890.txt').read()
t_data2
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n-------------------------
# ...

# %% [markdown]
# 형태소 분석기를 이용하여 단어 토큰화

# %%
from konlpy.tag import Okt
tw1=Okt()
s_data=tw1.nouns(t_data2)
s_data=[i for i in s_data if len(i)>1]
s_data
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '발의',
#  '연월일',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '제안',
#  '이유',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '육아휴직',
#  '자녀',
#  '나이',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '해당',
#  '부모님',
#  '일자리',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '이하',
#  '개정',
#  '것임',
#  '항제',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '항제',
#  '이하',
#  '초등학교',
#  '취학',
#  '자녀',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '자녀',
#  '공포',
#  '시행',
#  '구조',
#  '문대비',
#  '휴직',
#  '휴직',
#  '현행',
#  '공무원',
#  '다음',
#  '호의',
#  '하나',
#  '해당',
#  '사유',
#  '임용',
#  '휴직',
#  '다만',
#  '경우',
#  '대통령령',
#  '사정',
#  '현행',
#  '이하',
#  '초등학교',
#  '이하',
#  '취학',
#  '중인',
# ...

# %% [markdown]
# 만들어진 data를  단어 리스트를 이용하여 단어의 정형화의 결과를 출력하시오

# %%
import numpy as np

# %%
len(np.unique(s_data))
# Out:
# 174

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
t_k = Tokenizer()
t_k.fit_on_texts(s_data)
t_k.index_word
# Out:
# {1: '육아휴직',
#  2: '발생',
#  3: '이하',
#  4: '비용',
#  5: '경우',
#  6: '자녀',
#  7: '고용',
#  8: '공무원',
#  9: '지급',
#  10: '월급',
#  11: '체인',
#  12: '개정',
#  13: '연령',
#  14: '추가',
#  15: '급여',
#  16: '법률',
#  17: '가정',
#  18: '대체',
#  19: '초등학교',
#  20: '휴직',
#  21: '자료',
#  22: '다음',
#  23: '예상',
#  24: '이상',
#  25: '확률',
#  26: '수식',
#  27: '지방공무원법',
#  28: '일부',
#  29: '해당',
#  30: '항제',
#  31: '현행',
#  32: '추계',
#  33: '재정',
#  34: '가능',
#  35: '지방',
#  36: '교육',
#  37: '인력',
#  38: '현재',
#  39: '따라서',
#  40: '취학',
#  41: '사유',
#  42: '첨부',
#  43: '개정안',
#  44: '근로자',
#  45: '신청',
#  46: '대상자',
#  47: '고용노동부',
#  48: '현황',
#  49: '정의화',
#  50: '의원',
#  51: '발의',
#  52: '저학년',
#  53: '나이',
#  54: '양육',
#  55: '출산',
#  56: '것임',
#  57: '중인',
#  58: '학년',
#  59: '시행',
#  60: '임용',
#  61: '국가공무원',
#  62: '조정',
#  63: '요가',
#  64: '평균',
#  65: '미만',
#  66: '국가',
#  67: '대상',
#  68: '확대',
#  69: '관련',
#  70: '법령',
#  71: '때문',
#  72: '인건비',
#  73: '여부',
#  74: '수급',
#  75: '바탕',
# ...

# %%
t_k.texts_to_sequences(s_data)
# Out:
# [[27],
#  [28],
#  [12],
#  [16],
#  [49],
#  [50],
#  [81],
#  [51],
#  [51],
#  [82],
#  [49],
#  [83],
#  [84],
#  [85],
#  [86],
#  [87],
#  [88],
#  [89],
#  [90],
#  [91],
#  [50],
#  [92],
#  [93],
#  [94],
#  [19],
#  [52],
#  [5],
#  [95],
#  [96],
#  [97],
#  [53],
#  [38],
#  [8],
#  [6],
#  [54],
#  [1],
#  [6],
#  [53],
#  [3],
#  [19],
#  [52],
#  [6],
#  [29],
#  [98],
#  [99],
#  [55],
#  [100],
#  [101],
#  [102],
#  [56],
#  [39],
#  [1],
#  [6],
#  [13],
#  [3],
#  [12],
#  [56],
#  [30],
#  [16],
#  [27],
#  [28],
#  [12],
#  [16],
#  [27],
#  [28],
#  [22],
#  [12],
#  [30],
#  [3],
#  [19],
#  [40],
#  [6],
#  [3],
#  [40],
#  [57],
#  [5],
#  [19],
#  [58],
#  [3],
#  [6],
#  [103],
#  [59],
#  [104],
#  [105],
#  [20],
#  [20],
#  [31],
#  [8],
#  [22],
#  [106],
#  [107],
#  [29],
#  [41],
#  [60],
#  [20],
#  [108],
#  [5],
#  [109],
#  [110],
#  [31],
#  [3],
#  [19],
#  [3],
#  [40],
#  [57],
#  [5],
#  [6],
#  [54],
#  [19],
#  [58],
#  [3],
#  [111],
# ...
